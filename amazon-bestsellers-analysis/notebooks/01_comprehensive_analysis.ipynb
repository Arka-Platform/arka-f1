# %% [markdown]
# # Amazon India Bestsellers - Quantitative Research Analysis
#
# ## Research Objectives
# 1. Analyze pricing patterns and market segmentation
# 2. Examine rating and review distributions
# 3. Identify top authors, publishers, and formats
# 4. Explore relationships between price, rating, and popularity
# 5. Apply statistical methodologies for robust findings

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings('ignore')

# Set visualization style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
# %matplotlib inline

# %%
# Load data
df = pd.read_csv('../data/november_bestsellers_amazon_india.csv')
print(f"Dataset shape: {df.shape}")
print(f"Columns: {list(df.columns)}")
df.head()
